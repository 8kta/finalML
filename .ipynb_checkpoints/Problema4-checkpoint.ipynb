# %% [markdown]
# # Problema 4

# %%
from scipy import stats
import numpy as np
import pandas as pd 
import math
import matplotlib.pyplot as plt
from random import seed

from numpy import random

import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer

# %% [markdown]
# La ecuación del cono que se usara en este problema es
# $$\frac{x^2+y^2}{c^2}=(z-z_0)^2$$
# en donde $c=\frac{r}{h}$ en donde $h$ representa la altura del cono, $r$ el radio de la base del cono y $z_0$ es el vertice del cono.
# Luego entonces la ecuación del cono está dada por
# $$f(x,y)=\pm\frac{h}{r}\sqrt{x^2+y^2}+z_0.$$

# %%
alt = input('Height of the cone: \n')
radius = input('Radius of the base: \n')
vertex = input('Vertex of cone:\n')

alt = float(alt)
radius = float(radius)
vertex = float(vertex)
# Out:
# Height of the cone:
# 10
# Radius of the base:
# 4
# Vertex of cone:
# 0

# %%
def f(x,y):
    
        return alt/radius*(x**2+y**2)**(1/2)+vertex # + stats.norm.rvs(loc=0,scale= .01,size=len

# %%
f(1,1)
# Out:
# 3.5355339059327378

# %%
# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np


fig = plt.figure()
ax = fig.gca(projection='3d')

# Make data.
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
#R = np.sqrt(X**2 + Y**2)
#Z = np.cos(R)

# Plot the surface.
surf = ax.plot_surface(X, Y, f(X,Y), cmap='viridis',
                       linewidth=0, antialiased=False)

# Customize the z axis.
ax.set_zlim(-1, 13)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=2)

plt.show()

# %%
# list of random float between a range 50.50 to 500.50
randomFloatList_x = []
# Set a length of the list to 10
for i in range(0, 100):
    # any random float between 50.50 to 500.50
    # don't use round() if you need number as it is
    x_data = round(random.uniform(-10, 10), 4)
    randomFloatList_x.append(x_data)
    
randomFloatList_y = []
# Set a length of the list to 10
for i in range(0, 100):
    # any random float between 50.50 to 500.50
    # don't use round() if you need number as it is
    y_data = round(random.uniform(-10, 10), 4)
    randomFloatList_y.append(y_data)

# %%
X_data = pd.DataFrame(randomFloatList_x )
Y_data = pd.DataFrame(randomFloatList_y )

# %%
#X_part = np.linspace(-10, 10, 200)
#Y_part = np.linspace(-10, 10, 200)

#new_list_x = X_part[:]
#new_list_y = Y_part[:]

#x_data = random.shuffle(new_list_x.reshape(-1,1))
#y_data = random.random(new_list_y.reshape(-1,1))

df = pd.DataFrame(np.column_stack(( X_data , Y_data , 
                                   f(X_data,Y_data))), 
                  columns=["X", "Y", 'Z'])

df
# Out:
#          X       Y          Z
# 0  -0.4293  8.5416  21.380954
# 1  -7.0164 -2.1671  18.358614
# 2  -9.2382 -9.9075  33.865810
# 3   8.6500  5.1235  25.133736
# 4  -2.8528  5.9028  16.390072
# ..     ...     ...        ...
# 95 -9.3714 -6.7566  28.882822
# 96  1.5975  0.1354   4.008070
# 97  1.7543  4.3808  11.797504
# 98  1.2476  7.3406  18.614664
# 99 -0.1161 -7.7349  19.339428
#
# [100 rows x 3 columns]

# %%
# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np


fig = plt.figure()
ax = fig.gca(projection='3d')

# Make data.
#X = np.arange(-5, 5, 0.25)
#Y = np.arange(-5, 5, 0.25)
#X, Y = np.meshgrid(X, Y)
#R = np.sqrt(X**2 + Y**2)
#Z = np.cos(R)


# Plot the surface.
#surf = ax.plot_trisurf(df['X'].to_numpy(), df['Y'].to_numpy(), df['Z'].to_numpy(), 
                      # cmap=cm.coolwarm,
                       #linewidth=0, antialiased=True)
surf = ax.scatter3D(df['X'].to_numpy(),df['Y'].to_numpy(),
                    df['Z'].to_numpy(), c=df['Z'].to_numpy(), cmap='Greens')

# Customize the z axis.
ax.set_zlim(0, 30)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

ax.set_xlim(-10, 10)
ax.set_ylim(-10, 10)

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=.8, aspect=4)

plt.show()

# %%
def regression_model():
    model = Sequential()
    model.add(Dense(20, activation='relu', input_dim = 2 ))
    model.add(Dense(40, activation='relu'))
    model.add(Dense(1))
    
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
model = regression_model()
train_df = pd.DataFrame({'X' : randomFloatList_x, 'Y' : randomFloatList_y})
zeta = pd.DataFrame({'Z' : df['Z']})
train_df
# Out:
#          X       Y
# 0  -0.4293  8.5416
# 1  -7.0164 -2.1671
# 2  -9.2382 -9.9075
# 3   8.6500  5.1235
# 4  -2.8528  5.9028
# ..     ...     ...
# 95 -9.3714 -6.7566
# 96  1.5975  0.1354
# 97  1.7543  4.3808
# 98  1.2476  7.3406
# 99 -0.1161 -7.7349
#
# [100 rows x 2 columns]

# %%
resultados = model.fit( train_df ,  zeta, validation_split=0.3, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 3/3 - 1s - loss: 475.4474 - val_loss: 401.3921
# Epoch 2/100
# 3/3 - 0s - loss: 460.6533 - val_loss: 388.9584
# Epoch 3/100
# 3/3 - 0s - loss: 446.2241 - val_loss: 376.6061
# Epoch 4/100
# 3/3 - 0s - loss: 431.4742 - val_loss: 364.3756
# Epoch 5/100
# 3/3 - 0s - loss: 417.7534 - val_loss: 352.0146
# Epoch 6/100
# 3/3 - 0s - loss: 403.4692 - val_loss: 339.8933
# Epoch 7/100
# 3/3 - 0s - loss: 389.2495 - val_loss: 328.0034
# Epoch 8/100
# 3/3 - 0s - loss: 375.7400 - val_loss: 316.1477
# Epoch 9/100
# 3/3 - 0s - loss: 362.0867 - val_loss: 304.4722
# Epoch 10/100
# 3/3 - 0s - loss: 348.4879 - val_loss: 293.0978
# Epoch 11/100
# 3/3 - 0s - loss: 334.9869 - val_loss: 282.0001
# Epoch 12/100
# 3/3 - 0s - loss: 322.7580 - val_loss: 270.9181
# Epoch 13/100
# 3/3 - 0s - loss: 310.1623 - val_loss: 260.2582
# Epoch 14/100
# 3/3 - 0s - loss: 297.6005 - val_loss: 249.8890
# Epoch 15/100
# 3/3 - 0s - loss: 285.7719 - val_loss: 239.6892
# Epoch 16/100
# 3/3 - 0s - loss: 273.5646 - val_loss: 229.4797
# Epoch 17/100
# 3/3 - 0s - loss: 261.6621 - val_loss: 218.9636
# Epoch 18/100
# 3/3 - 0s - loss: 249.2686 - val_loss: 208.2373
# Epoch 19/100
# 3/3 - 0s - loss: 236.7727 - val_loss: 197.2949
# Epoch 20/100
# 3/3 - 0s - loss: 223.6608 - val_loss: 186.3714
# Epoch 21/100
# 3/3 - 0s - loss: 211.6518 - val_loss: 175.3843
# Epoch 22/100
# 3/3 - 0s - loss: 198.7876 - val_loss: 164.8200
# Epoch 23/100
# 3/3 - 0s - loss: 186.3458 - val_loss: 154.4197
# Epoch 24/100
# 3/3 - 0s - loss: 174.2477 - val_loss: 143.8926
# Epoch 25/100
# 3/3 - 0s - loss: 161.9896 - val_loss: 133.2936
# Epoch 26/100
# 3/3 - 0s - loss: 150.1916 - val_loss: 122.7300
# Epoch 27/100
# 3/3 - 0s - loss: 137.9219 - val_loss: 112.4142
# Epoch 28/100
# 3/3 - 0s - loss: 126.7808 - val_loss: 102.2277
# Epoch 29/100
# 3/3 - 0s - loss: 115.3060 - val_loss: 92.5401
# Epoch 30/100
# 3/3 - 0s - loss: 104.4582 - val_loss: 83.4514
# Epoch 31/100
# 3/3 - 0s - loss: 94.3816 - val_loss: 74.8659
# Epoch 32/100
# 3/3 - 0s - loss: 84.7433 - val_loss: 66.7472
# Epoch 33/100
# 3/3 - 0s - loss: 75.7916 - val_loss: 59.2572
# Epoch 34/100
# 3/3 - 0s - loss: 67.7744 - val_loss: 52.3650
# Epoch 35/100
# 3/3 - 0s - loss: 60.2598 - val_loss: 46.2335
# Epoch 36/100
# 3/3 - 0s - loss: 53.4162 - val_loss: 40.8079
# Epoch 37/100
# 3/3 - 0s - loss: 47.9122 - val_loss: 35.8314
# Epoch 38/100
# 3/3 - 0s - loss: 42.4228 - val_loss: 31.5883
# Epoch 39/100
# 3/3 - 0s - loss: 37.7150 - val_loss: 27.8553
# Epoch 40/100
# 3/3 - 0s - loss: 33.6058 - val_loss: 24.5102
# Epoch 41/100
# 3/3 - 0s - loss: 29.9233 - val_loss: 21.5941
# Epoch 42/100
# 3/3 - 0s - loss: 26.9015 - val_loss: 19.1145
# Epoch 43/100
# 3/3 - 0s - loss: 24.0755 - val_loss: 16.9926
# Epoch 44/100
# 3/3 - 0s - loss: 21.9632 - val_loss: 15.1028
# Epoch 45/100
# 3/3 - 0s - loss: 19.7106 - val_loss: 13.5083
# Epoch 46/100
# 3/3 - 0s - loss: 17.9747 - val_loss: 12.1111
# Epoch 47/100
# 3/3 - 0s - loss: 16.3565 - val_loss: 10.8642
# Epoch 48/100
# 3/3 - 0s - loss: 14.9537 - val_loss: 9.7597
# Epoch 49/100
# 3/3 - 0s - loss: 13.6742 - val_loss: 8.8409
# Epoch 50/100
# 3/3 - 0s - loss: 12.5836 - val_loss: 8.0583
# Epoch 51/100
# 3/3 - 0s - loss: 11.5973 - val_loss: 7.3555
# Epoch 52/100
# 3/3 - 0s - loss: 10.7681 - val_loss: 6.7593
# Epoch 53/100
# 3/3 - 0s - loss: 9.9788 - val_loss: 6.2407
# Epoch 54/100
# 3/3 - 0s - loss: 9.3147 - val_loss: 5.7891
# Epoch 55/100
# 3/3 - 0s - loss: 8.7755 - val_loss: 5.3944
# Epoch 56/100
# 3/3 - 0s - loss: 8.2234 - val_loss: 5.0479
# Epoch 57/100
# 3/3 - 0s - loss: 7.7441 - val_loss: 4.7480
# Epoch 58/100
# 3/3 - 0s - loss: 7.3147 - val_loss: 4.4827
# Epoch 59/100
# 3/3 - 0s - loss: 6.9523 - val_loss: 4.2553
# Epoch 60/100
# 3/3 - 0s - loss: 6.6096 - val_loss: 4.0655
# Epoch 61/100
# 3/3 - 0s - loss: 6.2801 - val_loss: 3.8908
# Epoch 62/100
# 3/3 - 0s - loss: 6.0137 - val_loss: 3.7352
# Epoch 63/100
# 3/3 - 0s - loss: 5.7096 - val_loss: 3.5808
# Epoch 64/100
# 3/3 - 0s - loss: 5.4484 - val_loss: 3.4151
# Epoch 65/100
# 3/3 - 0s - loss: 5.1927 - val_loss: 3.2638
# Epoch 66/100
# 3/3 - 0s - loss: 4.9565 - val_loss: 3.1231
# Epoch 67/100
# 3/3 - 0s - loss: 4.7245 - val_loss: 2.9862
# Epoch 68/100
# 3/3 - 0s - loss: 4.5132 - val_loss: 2.8491
# Epoch 69/100
# 3/3 - 0s - loss: 4.3146 - val_loss: 2.7224
# Epoch 70/100
# 3/3 - 0s - loss: 4.1346 - val_loss: 2.6047
# Epoch 71/100
# 3/3 - 0s - loss: 3.9603 - val_loss: 2.4927
# Epoch 72/100
# 3/3 - 0s - loss: 3.8044 - val_loss: 2.3917
# Epoch 73/100
# 3/3 - 0s - loss: 3.6506 - val_loss: 2.3017
# Epoch 74/100
# 3/3 - 0s - loss: 3.4976 - val_loss: 2.2208
# Epoch 75/100
# 3/3 - 0s - loss: 3.3571 - val_loss: 2.1458
# Epoch 76/100
# 3/3 - 0s - loss: 3.2215 - val_loss: 2.0706
# Epoch 77/100
# 3/3 - 0s - loss: 3.0897 - val_loss: 2.0055
# Epoch 78/100
# 3/3 - 0s - loss: 2.9653 - val_loss: 1.9393
# Epoch 79/100
# 3/3 - 0s - loss: 2.8376 - val_loss: 1.8799
# Epoch 80/100
# 3/3 - 0s - loss: 2.7164 - val_loss: 1.8250
# Epoch 81/100
# 3/3 - 0s - loss: 2.6059 - val_loss: 1.7706
# Epoch 82/100
# 3/3 - 0s - loss: 2.5030 - val_loss: 1.7165
# Epoch 83/100
# 3/3 - 0s - loss: 2.4079 - val_loss: 1.6684
# Epoch 84/100
# 3/3 - 0s - loss: 2.3217 - val_loss: 1.6232
# Epoch 85/100
# 3/3 - 0s - loss: 2.2206 - val_loss: 1.5754
# Epoch 86/100
# 3/3 - 0s - loss: 2.1421 - val_loss: 1.5354
# Epoch 87/100
# 3/3 - 0s - loss: 2.0496 - val_loss: 1.4946
# Epoch 88/100
# 3/3 - 0s - loss: 1.9708 - val_loss: 1.4480
# Epoch 89/100
# 3/3 - 0s - loss: 1.8911 - val_loss: 1.3976
# Epoch 90/100
# 3/3 - 0s - loss: 1.8137 - val_loss: 1.3481
# Epoch 91/100
# 3/3 - 0s - loss: 1.7380 - val_loss: 1.3039
# Epoch 92/100
# 3/3 - 0s - loss: 1.6584 - val_loss: 1.2552
# Epoch 93/100
# 3/3 - 0s - loss: 1.5968 - val_loss: 1.2032
# Epoch 94/100
# 3/3 - 0s - loss: 1.5196 - val_loss: 1.1685
# Epoch 95/100
# 3/3 - 0s - loss: 1.4616 - val_loss: 1.1467
# Epoch 96/100
# 3/3 - 0s - loss: 1.3944 - val_loss: 1.1296
# Epoch 97/100
# 3/3 - 0s - loss: 1.3402 - val_loss: 1.1167
# Epoch 98/100
# 3/3 - 0s - loss: 1.2925 - val_loss: 1.1023
# Epoch 99/100
# 3/3 - 0s - loss: 1.2404 - val_loss: 1.0769
# Epoch 100/100
# 3/3 - 0s - loss: 1.1977 - val_loss: 1.0456

# %%
plt.plot(resultados.history['loss'])
plt.plot(resultados.history['val_loss'])
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Entrenamiento', 'Validación'], loc='upper left')
plt.show()

# %%
test_x = []

for i in range(0, 1000):
    # any random float between 50.50 to 500.50
    # don't use round() if you need number as it is
    x_data = round(random.uniform(-10, 10), 4)
    test_x.append(x_data)
    
test_y = []
# Set a length of the list to 10
for i in range(0, 1000):
    # any random float between 50.50 to 500.50
    # don't use round() if you need number as it is
    y_data = round(random.uniform(-10, 10), 4)
    test_y.append(y_data)
    
X_test = pd.DataFrame(test_x)
Y_test = pd.DataFrame(test_y)

test_df = pd.DataFrame({'X' : test_x, 'Y' : test_y})

# %%
pred = model.predict(test_df)

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')

surf = ax.scatter3D(test_df['X'].to_numpy(),test_df['Y'].to_numpy(),
                    pred, c=pred, cmap='Greens')

# Customize the z axis.
ax.set_zlim(0, 30)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

# Customize the x,y axis.
ax.set_xlim(-10, 10)
ax.set_ylim(-10, 10)

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=.8, aspect=4)

plt.show()
